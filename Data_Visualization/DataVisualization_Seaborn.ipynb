# %%
import matplotlib as plt 
import seaborn as sns 
import numpy as np
import pandas as pd

import warnings
warnings.simplefilter("ignore")

# %%
df=pd.read_csv("tips.csv")
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.shape
# Out:
# (244, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
continuous=['total_bill','tip']
discrete_categorical=['sex',	'smoker',	'day',	'time']
discret_count=['size']

# %%
df[continuous].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
# dtypes: float64(2)
# memory usage: 3.9 KB

# %%
df[continuous].describe()
# Out:
#        total_bill         tip
# count  244.000000  244.000000
# mean    19.785943    2.998279
# std      8.902412    1.383638
# min      3.070000    1.000000
# 25%     13.347500    2.000000
# 50%     17.795000    2.900000
# 75%     24.127500    3.562500
# max     50.810000   10.000000

# %%
df[continuous].head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
df[continuous].max()
# Out:
# total_bill    50.81
# tip           10.00
# dtype: float64

# %%
df[discrete_categorical].describe()
# df['time'].unique()
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
df[continuous].skew()
# Out:
# total_bill    1.133213
# tip           1.465451
# dtype: float64

# %%
df.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
sns.histplot(df['total_bill'],bins=10,kde=True)
# plt.show()
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.boxplot(x=df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %%
sns.boxplot(x=df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
sns.scatterplot(x=df['total_bill'],y=df['tip'],hue=df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],hue=df['sex'],kind='line')

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],col=df['size'],col_wrap=3,hue=df['sex'],kind='scatter')

# %%
sns.relplot(x=df['total_bill'],y=df['tip'],col=df['sex'],col_wrap=2,hue=df['day'],kind='scatter')

# %%
sns.pairplot(df,vars=continuous)

# %%
cr=df[continuous].corr()

# %%
sns.heatmap(cr,annot=True)
# Out:
# <Axes: >

# %%
sns.countplot(x=df['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='count'>

# %%
df.groupby('sex')['total_bill'].mean()
# Out:
# sex
# Female    18.056897
# Male      20.744076
# Name: total_bill, dtype: float64

# %%
sns.catplot(x=df['smoker'],y=df['total_bill'],kind='bar',hue=df['sex'])

# %%
sns.jointplot(x=df['total_bill'],y=df['tip'])

# %%
sns.violinplot(x=df['total_bill'],y=df['sex'],hue=df['sex'])
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.catplot(x=df['day'],y=df['total_bill'],kind='box',hue=df['sex'])

# %%
df.groupby('day')['total_bill'].mean()
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64

# %%
pd.crosstab(df['day'],df['sex'],margins=True)
# Out:
# sex   Female  Male  All
# day
# Fri        9    10   19
# Sat       28    59   87
# Sun       18    58   76
# Thur      32    30   62
# All       87   157  244

# %%
df.groupby('time')['size'].sum()
# Out:
# time
# Dinner    463
# Lunch     164
# Name: size, dtype: int64

# %%
df.groupby('time')['size'].count()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: size, dtype: int64

# %%
df.groupby('time')['total_bill'].max()
# Out:
# time
# Dinner    50.81
# Lunch     43.11
# Name: total_bill, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
